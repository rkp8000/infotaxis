# %%
# %matplotlib inline
from demo import basic_plume_2d

basic_plume_2d.run()
# Out:
# Found source!

# %%
# %matplotlib inline
from demo import basic_plume_2d

basic_plume_2d.run()
# Out:
# Found source!
